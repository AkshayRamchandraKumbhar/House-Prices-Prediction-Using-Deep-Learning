# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("new_EDA.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0           0  221900         3          1         1180      5650       1
# 1           1  538000         3          2         2570      7242       2
# 2           2  180000         2          1          770     10000       1
# 3           3  604000         4          3         1960      5000       1
# 4           4  510000         3          2         1680      8080       1
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode  lat  long  sqft_living15  sqft_lot15
# ...

# %%
df.kurt()
# Out:
# Unnamed: 0        -1.200000
# price             34.585540
# bedrooms          49.063653
# bathrooms          1.989574
# sqft_living        5.243093
# sqft_lot         285.077820
# floors            -0.551411
# waterfront       127.632494
# view              10.893022
# condition          0.525764
# grade              1.190932
# sqft_above         3.402304
# sqft_basement      2.715574
# yr_built          -0.657408
# yr_renovated      18.701152
# zipcode           -0.853479
# lat                0.000000
# long               9.728654
# sqft_living15      1.597096
# sqft_lot15       150.763110
# dtype: float64

# %%
df.std()
# Out:
# Unnamed: 0         6239.280020
# price            367127.196483
# bedrooms              0.930062
# bathrooms             0.734873
# sqft_living         918.440897
# sqft_lot          41420.511515
# floors                0.551894
# waterfront            0.086517
# view                  0.766318
# condition             0.650743
# grade                 1.175459
# sqft_above          828.090978
# sqft_basement       442.575043
# yr_built             29.373411
# yr_renovated        401.679240
# zipcode              53.505026
# lat                   0.000000
# long                  0.252173
# sqft_living15       685.391304
# sqft_lot15        27304.179631
# dtype: float64

# %%
df.hist(figsize=(14,8))
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>],
#        [<AxesSubplot:title={'center':'sqft_living'}>,
#         <AxesSubplot:title={'center':'sqft_lot'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'waterfront'}>],
#        [<AxesSubplot:title={'center':'view'}>,
#         <AxesSubplot:title={'center':'condition'}>,
#         <AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>],
#        [<AxesSubplot:title={'center':'sqft_basement'}>,
#         <AxesSubplot:title={'center':'yr_built'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>,
#         <AxesSubplot:title={'center':'zipcode'}>],
#        [<AxesSubplot:title={'center':'lat'}>,
#         <AxesSubplot:title={'center':'long'}>,
# ...

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df["price"])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
# checking corr

# %%
df.corr().T
# Out:
#                Unnamed: 0     price  bedrooms  bathrooms  sqft_living  \
# Unnamed: 0       1.000000  0.027372  0.010794   0.099400     0.044717
# price            0.027372  1.000000  0.308350   0.510072     0.702035
# bedrooms         0.010794  0.308350  1.000000   0.467452     0.576671
# bathrooms        0.099400  0.510072  0.467452   1.000000     0.697875
# sqft_living      0.044717  0.702035  0.576671   0.697875     1.000000
# sqft_lot        -0.026877  0.089661  0.031703   0.085310     0.172826
# floors           0.185053  0.237211  0.155643   0.484822     0.353321
# waterfront      -0.007611  0.266369 -0.006582   0.058798     0.103818
# view            -0.013751  0.397293  0.079532   0.177257     0.284611
# condition       -0.095419  0.036362  0.028472  -0.126016    -0.058753
# grade            0.082050  0.667434  0.356967   0.606631     0.762704
# sqft_above       0.071958  0.605567  0.477600   0.639933     0.876597
# ...

# %%
# negatvie=-1
# no corr=0
# postive=+1

# %% [raw]
# with the help of correction we found
#
# Negative correction=["waterfront"]
#
# NO Corr=["sqft_lot","condition","yr_built","Zipcode","lat","long","sqft_lot15"]
#
# Psoitive corr=["bedrooms","bathrooms","sqft_living","view,"floors","grade","sqft_above","sqft_basement","yr_renovated","sqft_living15"]

# %%
sns.heatmap(df.corr(),annot=True,vmax=1,vmin=-1)
# Out:
# <AxesSubplot:>

# %%
# drop not useful feactures
data=df
data.head()
# Out:
#    Unnamed: 0   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0           0  221900         3          1         1180      5650       1
# 1           1  538000         3          2         2570      7242       2
# 2           2  180000         2          1          770     10000       1
# 3           3  604000         4          3         1960      5000       1
# 4           4  510000         3          2         1680      8080       1
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode  lat  long  sqft_living15  sqft_lot15
# ...

# %%
data.shape
# Out:
# (21613, 20)

# %%
data=data.drop(["sqft_lot"],axis=1)

# %%
data=data.drop(["Unnamed: 0"],axis=1)

# %%
data=data.drop(["condition"],axis=1)
data=data.drop(["yr_built"],axis=1)
data=data.drop(["zipcode"],axis=1)
data=data.drop(["lat"],axis=1)
data=data.drop(["long"],axis=1)
data=data.drop(["sqft_lot15"],axis=1)

# %%
data.head()
data.shape
# Out:
# (21613, 12)

# %%
df.shape
# Out:
# (21613, 20)

# %%
data.head()
# Out:
#     price  bedrooms  bathrooms  sqft_living  floors  waterfront  view  grade  \
# 0  221900         3          1         1180       1           0     0      7
# 1  538000         3          2         2570       2           0     0      7
# 2  180000         2          1          770       1           0     0      6
# 3  604000         4          3         1960       1           0     0      7
# 4  510000         3          2         1680       1           0     0      8
#
#    sqft_above  sqft_basement  yr_renovated  sqft_living15
# 0        1180              0             0           1340
# 1        2170            400          1991           1690
# 2         770              0             0           2720
# 3        1050            910             0           1360
# 4        1680              0             0           1800

# %%
sns.heatmap(data.corr(),annot=True,vmax=1,vmin=-1)
# Out:
# <AxesSubplot:>

# %%
data.hist(figsize=(14,8))
# Out:
# array([[<AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>],
#        [<AxesSubplot:title={'center':'sqft_living'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'waterfront'}>],
#        [<AxesSubplot:title={'center':'view'}>,
#         <AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>],
#        [<AxesSubplot:title={'center':'sqft_basement'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>,
#         <AxesSubplot:title={'center':'sqft_living15'}>]], dtype=object)

# %%
sns.pairplot(data=data)

# %%
data.kurt()
# Out:
# price             34.585540
# bedrooms          49.063653
# bathrooms          1.989574
# sqft_living        5.243093
# floors            -0.551411
# waterfront       127.632494
# view              10.893022
# grade              1.190932
# sqft_above         3.402304
# sqft_basement      2.715574
# yr_renovated      18.701152
# sqft_living15      1.597096
# dtype: float64

# %%
data.hist(figsize=(14,8))
# Out:
# array([[<AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>],
#        [<AxesSubplot:title={'center':'sqft_living'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'waterfront'}>],
#        [<AxesSubplot:title={'center':'view'}>,
#         <AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>],
#        [<AxesSubplot:title={'center':'sqft_basement'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>,
#         <AxesSubplot:title={'center':'sqft_living15'}>]], dtype=object)

# %%
data.kurt()
# Out:
# price             34.585540
# bedrooms          49.063653
# bathrooms          1.989574
# sqft_living        5.243093
# floors            -0.551411
# waterfront       127.632494
# view              10.893022
# grade              1.190932
# sqft_above         3.402304
# sqft_basement      2.715574
# yr_renovated      18.701152
# sqft_living15      1.597096
# dtype: float64

# %%
data.skew()
# Out:
# price             4.024069
# bedrooms          1.974300
# bathrooms         0.902105
# sqft_living       1.471555
# floors            0.726178
# waterfront       11.385108
# view              3.395750
# grade             0.771103
# sqft_above        1.446664
# sqft_basement     1.577965
# yr_renovated      4.549493
# sqft_living15     1.108181
# dtype: float64

# %%
#visualizing house prices
fig = plt.figure(figsize=(10,7))
fig.add_subplot(2,1,1)
sns.distplot(data['price'])
fig.add_subplot(2,1,2)
sns.boxplot(data['price'])
plt.tight_layout()

# %%
#visualizing square footage of (home,lot,above and basement)
fig = plt.figure(figsize=(16,5))
fig.add_subplot(2,2,1)
sns.scatterplot(data['sqft_above'], data['price'])
fig.add_subplot(2,2,2)

sns.scatterplot(data['sqft_living'],data['price'])
fig.add_subplot(2,2,4)
sns.scatterplot(data['sqft_basement'],data['price'])
# Out:
# <AxesSubplot:xlabel='sqft_basement', ylabel='price'>

# %%
data.to_csv("data.csv")

# %%
data.skew()
# Out:
# price             4.024069
# bedrooms          1.974300
# bathrooms         0.902105
# sqft_living       1.471555
# floors            0.726178
# waterfront       11.385108
# view              3.395750
# grade             0.771103
# sqft_above        1.446664
# sqft_basement     1.577965
# yr_renovated      4.549493
# sqft_living15     1.108181
# dtype: float64

# %%
data.hist(figsize=(14,8))
# Out:
# array([[<AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>],
#        [<AxesSubplot:title={'center':'sqft_living'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'waterfront'}>],
#        [<AxesSubplot:title={'center':'view'}>,
#         <AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>],
#        [<AxesSubplot:title={'center':'sqft_basement'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>,
#         <AxesSubplot:title={'center':'sqft_living15'}>]], dtype=object)

# %%
data.kurt()
# Out:
# price             34.585540
# bedrooms          49.063653
# bathrooms          1.989574
# sqft_living        5.243093
# floors            -0.551411
# waterfront       127.632494
# view              10.893022
# grade              1.190932
# sqft_above         3.402304
# sqft_basement      2.715574
# yr_renovated      18.701152
# sqft_living15      1.597096
# dtype: float64
